# %%
import pandas as pd
dataset1 = pd.read_csv("general_data.csv")
dataset1
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
import matplotlib.pyplot as plt

# %%
dataset2 = dataset1.isnull()
dataset2
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# ...     ...        ...             ...         ...               ...
# 4405  False      False           False       False             False
# 4406  False      False           False       False             False
# 4407  False      False           False       False             False
# 4408  False      False           False       False             False
# 4409  False      False           False       False             False
#
#       Education  EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %%
dataset3 = dataset1.dropna
dataset3
# Out:
# <bound method DataFrame.dropna of       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset4 = dataset1.duplicated()
dataset4
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
dataset5 = dataset1.drop_duplicates()
dataset5
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset7 = dataset1.head(25)
dataset7
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 0    51        No      Travel_Rarely                   Sales
# 1    31       Yes  Travel_Frequently  Research & Development
# 2    32        No  Travel_Frequently  Research & Development
# 3    38        No         Non-Travel  Research & Development
# 4    32        No      Travel_Rarely  Research & Development
# 5    46        No      Travel_Rarely  Research & Development
# 6    28       Yes      Travel_Rarely  Research & Development
# 7    29        No      Travel_Rarely  Research & Development
# 8    31        No      Travel_Rarely  Research & Development
# 9    25        No         Non-Travel  Research & Development
# 10   45        No      Travel_Rarely  Research & Development
# 11   36        No      Travel_Rarely  Research & Development
# 12   55        No      Travel_Rarely  Research & Development
# 13   47       Yes         Non-Travel  Research & Development
# ...

# %%
dataset7.median()
# Out:
# Age                           36.0
# DistanceFromHome               8.0
# Education                      3.0
# EmployeeCount                  1.0
# EmployeeID                    13.0
# JobLevel                       1.0
# MonthlyIncome              55380.0
# NumCompaniesWorked             1.0
# PercentSalaryHike             13.0
# StandardHours                  8.0
# StockOptionLevel               1.0
# TotalWorkingYears             10.0
# TrainingTimesLastYear          2.0
# YearsAtCompany                 6.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           4.0
# dtype: float64

# %%
dataset7.mode()
# Out:
#      Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0   28.0        No  Travel_Rarely  Research & Development               1.0
# 1   29.0       NaN            NaN                     NaN               NaN
# 2   31.0       NaN            NaN                     NaN               NaN
# 3   32.0       NaN            NaN                     NaN               NaN
# 4   37.0       NaN            NaN                     NaN               NaN
# 5   38.0       NaN            NaN                     NaN               NaN
# 6    NaN       NaN            NaN                     NaN               NaN
# 7    NaN       NaN            NaN                     NaN               NaN
# 8    NaN       NaN            NaN                     NaN               NaN
# 9    NaN       NaN            NaN                     NaN               NaN
# 10   NaN       NaN            NaN                     NaN               NaN
# ...

# %%
dataset7.describe()
# Out:
#              Age  DistanceFromHome  Education  EmployeeCount  EmployeeID  \
# count  25.000000         25.000000  25.000000           25.0   25.000000
# mean   36.880000          8.440000   2.960000            1.0   13.000000
# std     9.475055          6.952697   1.171893            0.0    7.359801
# min    21.000000          1.000000   1.000000            1.0    1.000000
# 25%    29.000000          2.000000   2.000000            1.0    7.000000
# 50%    36.000000          8.000000   3.000000            1.0   13.000000
# 75%    45.000000         11.000000   4.000000            1.0   19.000000
# max    55.000000         28.000000   5.000000            1.0   25.000000
#
#         JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  25.000000      25.000000           25.000000          25.000000
# mean    1.800000   64714.400000            1.720000          14.720000
# std     1.040833   42240.976954            1.646208           4.118252
# ...

# %%
dataset7.var()
# Out:
# Age                        8.977667e+01
# DistanceFromHome           4.834000e+01
# Education                  1.373333e+00
# EmployeeCount              0.000000e+00
# EmployeeID                 5.416667e+01
# JobLevel                   1.083333e+00
# MonthlyIncome              1.784300e+09
# NumCompaniesWorked         2.710000e+00
# PercentSalaryHike          1.696000e+01
# StandardHours              0.000000e+00
# StockOptionLevel           1.290000e+00
# TotalWorkingYears          8.051449e+01
# TrainingTimesLastYear      1.743333e+00
# YearsAtCompany             5.826000e+01
# YearsSinceLastPromotion    1.369333e+01
# YearsWithCurrManager       1.341000e+01
# dtype: float64

# %%
dataset7.skew()
# Out:
# Age                        0.409151
# DistanceFromHome           0.976892
# Education                 -0.423328
# EmployeeCount              0.000000
# EmployeeID                 0.000000
# JobLevel                   1.156779
# MonthlyIncome              1.441524
# NumCompaniesWorked         1.524636
# PercentSalaryHike          0.987857
# StandardHours              0.000000
# StockOptionLevel           0.657890
# TotalWorkingYears          1.372856
# TrainingTimesLastYear      1.102910
# YearsAtCompany             2.248743
# YearsSinceLastPromotion    0.846106
# YearsWithCurrManager       0.429090
# dtype: float64

# %%
dataset7.kurt()
# Out:
# Age                       -0.835964
# DistanceFromHome           0.964528
# Education                 -0.853045
# EmployeeCount              0.000000
# EmployeeID                -1.200000
# JobLevel                   0.222560
# MonthlyIncome              2.287233
# NumCompaniesWorked         3.060116
# PercentSalaryHike         -0.395377
# StandardHours              0.000000
# StockOptionLevel          -0.993142
# TotalWorkingYears          1.455287
# TrainingTimesLastYear     -0.274406
# YearsAtCompany             6.456594
# YearsSinceLastPromotion   -0.776812
# YearsWithCurrManager      -0.517618
# dtype: float64

# %% [markdown]
# # HYPOTHESIS STATEMENTS
#
# 1. The Mean age of employee with an attrition is 34 and the std dev is 15. For sample of first 25 employees mean age is found to be 36. The Mean is 32. level of significance = 0.05
#
# 2. For first 25 Employees, If the employees monthly income is greater than equal to 64,700, then employees will not leave the company.Std dev is unknown.
#
# 3. If percent salary hike is equal to 14. Then employees will leave the company,then Mean is 14. Std dev is 14.
#
# 4. For first 25 Employees. If the employees monthly income is less than equal to 64,700. Then employees will leave the company.Std deviation is unknown.
#
# 5. If any Female Employee is unmarried and in future she decides to marry,then she has to leave the job.
#
# 6. If any Employee does not complete his target in time,then he will be fired from the job.
#
# 7. If the Mean total years of working is greater than or equal to 12,then he will not leave the job.
